# %%
import pandas as pd

# %%
df = pd.read_csv("F:/trainity/Project 5/IMDB_Movies_new1.csv")

# %%
df.head()

# %%
df.isnull().sum()
# Out:
# movie_title                0
# director_name              0
# actor_1_name               0
# duration                   0
#  gross                     0
#  budget                    0
# num_critic_for_reviews     0
# director_facebook_likes    0
# actor_1_facebook_likes     0
# num_voted_users            0
# num_user_for_reviews       0
# language                   1
# country                    0
# title_year                 0
# imdb_score                 0
# movie_facebook_likes       0
# genre1                     0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
y = []
for i in range(len(df)):
    x = tuple(df.iloc[i])
    y.append(x)

# %%
y
# Out:
# [('Avatar ',
#   'James Cameron',
#   'CCH Pounder',
#   178,
#   760505847,
#   237000000,
#   723,
#   0,
#   1000,
#   886204,
#   3054,
#   'English',
#   'USA',
#   2009,
#   7.9,
#   33000,
#   'Action'),
#  ("Pirates of the Caribbean: At World's End ",
#   'Gore Verbinski',
#   'Johnny Depp',
#   169,
#   309404152,
#   300000000,
#   302,
#   563,
#   40000,
#   471220,
#   1238,
#   'English',
#   'USA',
#   2007,
#   7.1,
#   0,
#   'Action'),
#  ('Spectre ',
#   'Sam Mendes',
#   'Christoph Waltz',
#   148,
#   200074175,
#   245000000,
#   602,
#   0,
#   11000,
#   275868,
#   994,
#   'English',
#   'UK',
#   2015,
#   6.8,
#   85000,
#   'Action'),
#  ('The Dark Knight Rises ',
#   'Christopher Nolan',
#   'Tom Hardy',
#   164,
#   448130642,
#   250000000,
#   813,
#   22000,
#   27000,
#   1144337,
#   2701,
#   'English',
#   'USA',
#   2012,
#   8.5,
#   164000,
#   'Action'),
#  ('John Carter ',
#   'Andrew Stanton',
#   'Daryl Sabara',
#   132,
#   73058679,
# ...

# %%
file = open("F:/trainity/Project 5/IMDB_Movies_new1.txt",'w')

for tuple in y:
    file.write(str(tuple) + ',' + '\n')

file.close()

# %%
df.dtypes
# Out:
# movie_title                 object
# director_name               object
# actor_1_name                object
# duration                     int64
#  gross                       int64
#  budget                      int64
# num_critic_for_reviews       int64
# director_facebook_likes      int64
# actor_1_facebook_likes       int64
# num_voted_users              int64
# num_user_for_reviews         int64
# language                    object
# country                     object
# title_year                   int64
# imdb_score                 float64
# movie_facebook_likes         int64
# genre1                      object
# dtype: object
